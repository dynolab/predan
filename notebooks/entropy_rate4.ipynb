# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sys.path.append('../bin')
from bin.functions import *
from bin.permutation import *
from bin.markov_permutation import *
from bin.entropy import *
np.seterr(all = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
ent_series = []
for i in range(1000):
    rw = generate_rw(10000)
    ent_series.append(permutation_entropy_rate(rw, 4))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 for i in range(1000):
#       3     rw = generate_rw(10000)
# ----> 4     ent_series.append(permutation_entropy_rate(rw, 4))
#
# File ~\Work\predan\bin\entropy.py:116, in permutation_entropy_rate(time_series, window, num_transitions)
#     115 def permutation_entropy_rate(time_series: pd.Series, window: int, num_transitions: int = 0) -> float:
# --> 116     permutation = permutation_series(time_series, window)
#     117     transition_matrix = compute_transition_matrix(permutation)
#     119     matrix_dot = transition_matrix.copy()
#
# File ~\Work\predan\notebooks\../bin\permutation.py:56, in permutation_series(ts, window)
#      54 real_ts = remove_consecutive_duplicates(ts.copy())
#      55 for i in range(real_ts.size - window + 1):
# ---> 56     slice_df = real_ts.copy().iloc[i:i + window]
# ...

# %%
len(ent_series)
# Out:
# 629

# %%
np.mean(ent_series)
# Out:
# 1.8727114755866434

# %%
np.max(ent_series)
# Out:
# 1.8961952471215957

# %%
np.min(ent_series)
# Out:
# 1.8431990286070579

# %%
np.median(ent_series)
# Out:
# 1.8732992600966205
