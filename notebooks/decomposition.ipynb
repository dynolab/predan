# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sys.path.append('../bin')
from bin.functions import *
from bin.permutation import *
from bin.markov_permutation import *
from bin.entropy import *
np.seterr(all = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
data = random_walk()
data.name = 'ts'
data.head()
# Out:
# C:\Users\vitya\Work\predan\bin\functions.py:56: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   time_series = pd.date_range(start=date_start, end=date_end, freq='H').to_series()
# C:\Users\vitya\Work\predan\bin\functions.py:58: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5000.0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   time_series[date_start] = 5000.0
# 2023-06-29 00:00:00         5000.0
# 2023-06-29 01:00:00    4988.797436
# 2023-06-29 02:00:00    4996.221217
# 2023-06-29 03:00:00    4991.100894
# 2023-06-29 04:00:00    4984.361319
# Name: ts, dtype: object

# %%
from statsmodels.tsa.seasonal import seasonal_decompose


# Perform time series decomposition
result = seasonal_decompose(data, model='additive')

# Plot the decomposed components
result.plot()
plt.show()

# %%
data = generate_ts(season=10, max_kf=100)
data.name = 'ts'
data.head()
# Out:
# C:\Users\vitya\Work\predan\bin\functions.py:28: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   time_series = pd.date_range(start=date_start, end=date_end, freq='H').to_series()
# C:\Users\vitya\Work\predan\bin\functions.py:30: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   time_series[0] = 5000.0
# C:\Users\vitya\Work\predan\bin\functions.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5000.0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   time_series[0] = 5000.0
# ...

# %%
result = seasonal_decompose(data, model='additive')

# Plot the decomposed components
result.plot()
plt.show()

# %%
for i in range(10):
    _, ts = generate_trend_series(1000)
    p_ts = permutation_series(ts, 4)
    mutual_info = mutual_info_score(p_rw, p_ts)
    print(mutual_info)
# Out:
# 0.08717260677716317
# 0.09786600777445494
# 0.07896883378054959
# 0.09031007034391667
# 0.08332047823411182
# 0.08248161683256207
# 0.054782696434932145
# 0.09760793930516722
# 0.0986517217937349
# 0.09097536281690241

# %%
for i in range(10):
    ts = generate_arma(10, 5, 1000)
    p_ts = permutation_series(ts, 4)
    mutual_info = mutual_info_score(p_rw, p_ts)
    print(mutual_info)
# Out:
# 0.2937200863808507
# 0.196123568713456
# 0.34828061563734286
# 0.32058952700584287
# 0.29588529055296814
# 0.2364045034491105
# 0.3080904018726575
# 0.28584661978557907
# 0.2602114607670622
# 0.24675804368772522
